# %%
import sys
from PyQt5 import uic
from PyQt5.QtWidgets import QWidget

class ChartWidget(QWidget):
    def __init__(self, parent=None, ticker="BTC"):
        super().__init__(parent)
        uic.loadUi("chart.ui")
        self.ticker = ticker

import sys
from PyQt5.QtWidgets import QApplication
app = QApplication(sys.argv)
cw = ChartWidget()
cw.show()
exit(app.exec_())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-bd3f9b8e966a> in <module>
#      12 from PyQt5.QtWidgets import QApplication
#      13 app = QApplication(sys.argv)
# ---> 14 cw = ChartWidget()
#      15 cw.show()
#      16 exit(app.exec_())
#
# <ipython-input-1-bd3f9b8e966a> in __init__(self, parent, ticker)
#       6     def __init__(self, parent=None, ticker="BTC"):
#       7         super().__init__(parent)
# ----> 8         uic.loadUi("chart.ui")
#       9         self.ticker = ticker
#      10
#
# ~\anaconda3\lib\site-packages\PyQt5\uic\__init__.py in loadUi(uifile, baseinstance, package, resource_suffix)
#     236     from .Loader.loader import DynamicUILoader
#     237
# --> 238     return DynamicUILoader(package).loadUi(uifile, baseinstance, resource_suffix)
#     239
#     240
#
# ~\anaconda3\lib\site-packages\PyQt5\uic\Loader\loader.py in loadUi(self, filename, toplevelInst, resource_suffix)
#      64         self.toplevelInst = toplevelInst
#      65
# ---> 66         return self.parse(filename, resource_suffix)
#
# ~\anaconda3\lib\site-packages\PyQt5\uic\uiparser.py in parse(self, filename, resource_suffix)
#    1035             elem = document.find(tagname)
#    1036             if elem is not None:
# -> 1037                 actor(elem)
#    1038         self.finalize()
#    1039         w = self.toplevelWidget
#
# ~\anaconda3\lib\site-packages\PyQt5\uic\uiparser.py in createUserInterface(self, elem)
#     826         self.wprops.setProperties(self.toplevelWidget, elem)
#     827         self.stack.push(self.toplevelWidget)
# --> 828         self.traverseWidgetTree(elem)
#     829         self.stack.popWidget()
#     830         self.addActions()
#
# ~\anaconda3\lib\site-packages\PyQt5\uic\uiparser.py in traverseWidgetTree(self, elem)
#     804                 continue
#     805
# --> 806             handler(self, child)
#     807
#     808     def createUserInterface(self, elem):
#
# ~\anaconda3\lib\site-packages\PyQt5\uic\uiparser.py in createLayout(self, elem)
#     501             elem.attrib["name"] = classname[1:].lower()
#     502         self.stack.push(self.setupObject(classname, parent, elem))
# --> 503         self.traverseWidgetTree(elem)
#     504
#     505         layout = self.stack.popLayout()
#
# ~\anaconda3\lib\site-packages\PyQt5\uic\uiparser.py in traverseWidgetTree(self, elem)
#     804                 continue
#     805
# --> 806             handler(self, child)
#     807
#     808     def createUserInterface(self, elem):
#
# ~\anaconda3\lib\site-packages\PyQt5\uic\uiparser.py in handleItem(self, elem)
#     544         if self.stack.topIsLayout():
#     545             elem[0].attrib['layout-position'] = _layout_position(elem)
# --> 546             self.traverseWidgetTree(elem)
#     547         else:
#     548             w = self.stack.topwidget
#
# ~\anaconda3\lib\site-packages\PyQt5\uic\uiparser.py in traverseWidgetTree(self, elem)
#     804                 continue
#     805
# --> 806             handler(self, child)
#     807
#     808     def createUserInterface(self, elem):
#
# ~\anaconda3\lib\site-packages\PyQt5\uic\uiparser.py in createWidget(self, elem)
#     262             parent = None
#     263
# --> 264         self.stack.push(self.setupObject(widget_class, parent, elem))
#     265
#     266         if isinstance(self.stack.topwidget, QtWidgets.QTableWidget):
#
# ~\anaconda3\lib\site-packages\PyQt5\uic\uiparser.py in setupObject(self, clsname, parent, branch, is_attribute)
#     226             args = (parent, )
#     227
# --> 228         obj = self.factory.createQObject(clsname, name, args, is_attribute)
#     229
#     230         self.wprops.setProperties(obj, branch)
#
# ~\anaconda3\lib\site-packages\PyQt5\uic\objcreator.py in createQObject(self, classname, *args, **kwargs)
#      98     def createQObject(self, classname, *args, **kwargs):
#      99         # Handle regular and custom widgets.
# --> 100         factory = self.findQObjectType(classname)
#     101
#     102         if factory is None:
#
# ~\anaconda3\lib\site-packages\PyQt5\uic\objcreator.py in findQObjectType(self, classname)
#     123     def findQObjectType(self, classname):
#     124         for module in self._modules:
# --> 125             w = module.search(classname)
#     126             if w is not None:
#     127                 return w
#
# ~\anaconda3\lib\site-packages\PyQt5\uic\Loader\qobjectcreator.py in search(self, cls)
#     111
#     112             try:
# --> 113                 module = __import__(mname, {}, {}, (cls,))
#     114             except ValueError:
#     115                 # Raise a more helpful exception.
#
# ModuleNotFoundError: No module named 'qchartview'
